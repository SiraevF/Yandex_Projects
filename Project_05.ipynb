# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# <h2>Содержание<span class="tocSkip"></span></h2>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-модулей" data-toc-modified-id="Загрузка-модулей-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка модулей</a></span></li><li><span><a href="#Настройки" data-toc-modified-id="Настройки-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Настройки</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Вывод-этапа" data-toc-modified-id="Вывод-этапа-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Вывод этапа</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Удаление-пропусков" data-toc-modified-id="Удаление-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Удаление пропусков</a></span></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Вывод-этапа" data-toc-modified-id="Вывод-этапа-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод этапа</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Удаление-признаков" data-toc-modified-id="Удаление-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Удаление признаков</a></span></li><li><span><a href="#Категориальные-признаки" data-toc-modified-id="Категориальные-признаки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Категориальные признаки</a></span></li><li><span><a href="#Разбиение" data-toc-modified-id="Разбиение-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Разбиение</a></span></li><li><span><a href="#Масштабирование" data-toc-modified-id="Масштабирование-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Масштабирование</a></span></li><li><span><a href="#Дисбаланс" data-toc-modified-id="Дисбаланс-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Дисбаланс</a></span></li><li><span><a href="#Вывод-этапа" data-toc-modified-id="Вывод-этапа-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Вывод этапа</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Вывод-этапа" data-toc-modified-id="Вывод-этапа-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод этапа</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Вывод-этапа" data-toc-modified-id="Вывод-этапа-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Вывод этапа</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка модулей

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
#from pandas_profiling import ProfileReport

from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score, roc_curve, ConfusionMatrixDisplay, confusion_matrix
from sklearn.svm import SVC
from sklearn.impute import KNNImputer

from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random

import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# ### Настройки

# %%
RANDOM_STATE = 12345
state = np.random.RandomState(RANDOM_STATE)
# Цветовая палитра документа
cm = 'crest'
mec = 'gray'
alpha = 0.7
fontsize = 14
figsize_base = 5

def new_color(x='r'):
    '''Цвет графиков, по умолчанию случайный из заданной цветовой палитры. Принимает в качестве аргумента число, \
    соответствующее цвету в палитре.'''
    if x == 'r':
        return list(sns.color_palette(cm, 20)[random.randint(0,19)])
    return list(sns.color_palette(cm, 20)[x])
# Размеры

def figsize(width = 1, height=1):
    '''Задание размеров окна отрисовки.'''
    return (width*figsize_base, height*figsize_base)

# Отрисовка 
def plot_set(ax,title='',xlabel='',ylabel='',fontsize=fontsize,xrot=True,figsize=figsize()):
    '''Функция для отрисовки дополнительных параметров графиков. Подписьи осей и названия, размер шрифта и размер окна, 
    включение сетки.'''
    plt.xticks(rotation=90*int(xrot), fontsize=fontsize)
    plt.yticks(fontsize=fontsize)
    plt.title(title+'\n', fontsize=fontsize)
    plt.xlabel('\n'+xlabel, fontsize=fontsize)
    plt.ylabel(ylabel+'\n', fontsize=fontsize)
    plt.grid(True)
    None
    
def mean_percent(x):
    '''Функция для форматирования значений. Округление до сотых и знак процента.'''
    try:
        return "{0:.2%}".format(x)
    except:
        return x

# %% [markdown]
# ### Загрузка данных

# %%
data = pd.read_csv('Churn.csv')

# %%
#profile = ProfileReport(data)
#profile.to_widgets()

# %%
data.head(25)
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602   Hargrave          619    France  Female   42
# 1           2    15647311       Hill          608     Spain  Female   41
# 2           3    15619304       Onio          502    France  Female   42
# 3           4    15701354       Boni          699    France  Female   39
# 4           5    15737888   Mitchell          850     Spain  Female   43
# 5           6    15574012        Chu          645     Spain    Male   44
# 6           7    15592531   Bartlett          822    France    Male   50
# 7           8    15656148     Obinna          376   Germany  Female   29
# 8           9    15792365         He          501    France    Male   44
# 9          10    15592389         H?          684    France    Male   27
# 10         11    15767821     Bearce          528    France    Male   31
# 11         12    15737173    Andrews          497     Spain    Male   24
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.isna().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %%
data.isna().mean().apply(mean_percent)
# Out:
# RowNumber          0.00%
# CustomerId         0.00%
# Surname            0.00%
# CreditScore        0.00%
# Geography          0.00%
# Gender             0.00%
# Age                0.00%
# Tenure             9.09%
# Balance            0.00%
# NumOfProducts      0.00%
# HasCrCard          0.00%
# IsActiveMember     0.00%
# EstimatedSalary    0.00%
# Exited             0.00%
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ### Вывод этапа

# %% [markdown]
# Изучен датафрейм `Churn.csv`:
# - 14 столбцов:
#     - `RowNumber` — индекс строки в данных
#     - `CustomerId` — уникальный идентификатор клиента
#     - `Surname` — фамилия
#     - `CreditScore` — кредитный рейтинг
#     - `Geography` — страна проживания
#     - `Gender` — пол
#     - `Age` — возраст
#     - `Tenure` — сколько лет человек является клиентом банка
#     - `Balance` — баланс на счёте
#     - `NumOfProducts` — количество продуктов банка, используемых клиентом
#     - `HasCrCard` — наличие кредитной карты
#     - `IsActiveMember` — активность клиента
#     - `EstimatedSalary` — предполагаемая зарплата
# - 10000 строк
# - Пропуски в строкe `Tenure` - 9.09% данных пропущено
# - Дубликатов не наблюдается
# - Типы всех столбцов кроме `Tenure` соответствуют содержанию. Необходимо поменять на `int` после обработки
# - Столбец `RowNumber` не несёт в себе дополнительного смысла, не будет участвовать в анализе.
# - Столбец `Surname`$^*$ избыточен, поскольку есть `CustomerId` - идентификатор.

# %% [markdown]
# $^*$ Вообще интерестно, можно ли считать фамилию в данном контексте персональными данными и использовать в анализе.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# Было установлено, что в столбце `Tenure` содержатся пропуски, около 9%. Посмотрим, можно ли их заполнить на основе других столбцов. Проверим, есть ли корреляция хоть с одним.

# %%
data_heat = data.drop(['Surname', 'CreditScore', 'Geography', 'Gender'],axis=1)
plt.figure(figsize=figsize(2,2))
sns.heatmap(data_heat.corr(), annot=True, cmap=cm, fmt='.2f')
None

# %% [markdown]
# Корреляции не обнаружено, значит на основе других столбцов заполнить не получиться. Варианты:
# - Заменить минимальным значением
# - Заменить медианным значением
# - Заменить -1 как отдельной категорией
#
# Посмотрим на распределение значений:

# %%
plt.figure(figsize=figsize())
ax1 = sns.histplot(data['Tenure'],color=new_color(),alpha=alpha)
plot_set(ax1,title='Распределение сроков',xlabel='Срок пользования',ylabel='Количество',xrot=False)

# %% [markdown]
# Распределение довольно равномерно, если не считать наибольший и наименьший сроки, их меньше. Замена первым или вторым вариантом внесут искажения. Первый вариант можно хотя бы аргументировать - срок 0, поэтому данные не внесли. Заполним пропуски на основе К ближайших соседей.

# %%
data_tenure_notna = data[data['Tenure'].notna()].drop(['Exited','RowNumber','CustomerId','Surname'], axis=1)
data_tenure_isna = data[data['Tenure'].isna()].drop(['Exited','RowNumber','CustomerId','Surname'], axis=1)

data_tenure_notna.head()

categorial = ['Geography','Gender']

encoder = OrdinalEncoder()
encoder.fit(data_tenure_notna[categorial])

data_tenure_notna[categorial] = encoder.transform(data_tenure_notna[categorial])
data_tenure_isna[categorial] = encoder.transform(data_tenure_isna[categorial])

model = KNNImputer()
model.fit(data_tenure_notna)
predict_tenure = model.transform(data_tenure_isna)[:,4]
data.loc[data['Tenure'].isna(),'Tenure'] = predict_tenure.round()

# %%
data.isna().mean().apply(mean_percent)
# Out:
# RowNumber          0.00%
# CustomerId         0.00%
# Surname            0.00%
# CreditScore        0.00%
# Geography          0.00%
# Gender             0.00%
# Age                0.00%
# Tenure             0.00%
# Balance            0.00%
# NumOfProducts      0.00%
# HasCrCard          0.00%
# IsActiveMember     0.00%
# EstimatedSalary    0.00%
# Exited             0.00%
# dtype: object

# %%
plt.figure(figsize=figsize())
ax1 = sns.histplot(data['Tenure'],color=new_color(),alpha=alpha)
plot_set(ax1,title='Распределение числа звонков',xlabel='Число звонков',ylabel='Количество',xrot=False)

# %% [markdown]
# Распределение несколько изменилось, но не так сильно, как если бы замена была на одно значение

# %%
data['Tenure'] = data['Tenure'].astype('int')
None

# %% [markdown]
# ### Поиск дубликатов

# %% [markdown]
# CustomerId — является идентификатором пользователя. Проверим на наличие повторений.

# %%
data['CustomerId'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод этапа

# %% [markdown]
# - Пропуски в столбце `Tenure` заменены на `-1`
# - Формат столбца `Tenure` изменён на `int`
# - Дубликатов в `CustomerId` не обнаружено

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Удаление признаков

# %%
for_drop = ['RowNumber','CustomerId', 'Surname']
data_ml = data.drop(for_drop, axis=1)
data_ml.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ### Разбиение

# %%
features = data_ml.drop('Exited', axis=1)
target = data_ml['Exited']

# %%
features_train, features_not_train, target_train, target_not_train = train_test_split(
    features, target, test_size=0.3, stratify=target, random_state=RANDOM_STATE)

# %%
features_valid, features_test, target_valid, target_test = train_test_split(
    features_not_train, target_not_train, test_size=0.5, stratify=target_not_train, random_state=RANDOM_STATE)

# %%
print("Размер обучающей выборки:", features_train.shape, 
      "\nРазмер валидационной выборки:", features_valid.shape, 
      "\nРазмер тестовой выборки:",features_test.shape)
# Out:
# Размер обучающей выборки: (7000, 10)
# Размер валидационной выборки: (1500, 10)
# Размер тестовой выборки: (1500, 10)

# %% [markdown]
# ### Масштабирование

# %%
numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# %%
scaler = StandardScaler()
scaler.fit(features_train[numeric])
None

# %%
features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

# %%
categorial = ['Geography','Gender']

# %%
encoder = OrdinalEncoder()
encoder.fit(features_train[categorial])
None

# %%
features_train[categorial] = encoder.transform(features_train[categorial])
features_valid[categorial] = encoder.transform(features_valid[categorial])
features_test[categorial] = encoder.transform(features_test[categorial])

# %%
features_valid.head()
# Out:
#       CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 4956     0.103453        2.0     1.0 -0.569933 -1.079895  0.066421
# 6553    -0.123842        1.0     1.0  1.057938 -1.439501  0.421623
# 3052    -0.444121        0.0     1.0 -0.378418 -1.079895 -1.221955
# 7970     2.066455        0.0     1.0 -0.857204  0.358527  0.162289
# 3413    -0.464784        0.0     1.0  0.004610 -0.360684 -1.221955
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 4956      -0.920635          0               0         0.867076
# 6553      -0.920635          1               0         1.178886
# 3052       0.810812          1               1         0.237255
# 7970      -0.920635          1               1         1.534355
# 3413       0.810812          1               0         1.718288

# %% [markdown]
# ### Дисбаланс

# %%
data['Exited'].value_counts().plot(
    kind = 'pie',
    autopct = '%1.0f%%',
    figsize=figsize(), 
    title = 'Распределение пользователей по подпискам',
    colors=[new_color(3),new_color(13)],explode = (0.05,0), shadow=True);
plt.ylabel('')
None

# %% [markdown]
# ### Вывод этапа

# %% [markdown]
# - Из рассмотрения убраны столбцы `RowNumber`,`CustomerId`, `Surname` как не несущие обучающей нагрузки
# - Категориальные данные из столбцов `Geography` и `Gender` подготовлены методом `OHE`
# - Проведено разбиение на обучающую, валидационную и тестовую выборки в соотношении 70%, 15% и 15% соответственно
# - Проведено маштабирование количественных данных
# - Установлено, что есть дисбаланс в целевом столбце. Значений `0` в 4 раза больше чем значений `1`

# %% [markdown]
# ## Обучение

# %% [markdown]
# Будем следить отдельно за лучшей среди всех моделей

# %%
best_model_all = None
best_f1_all = 0

# %% [markdown]
# ### Дерево решений

# %% [markdown]
# Обучим модели без учета дисбаланса, и посмотрим на ключевые метрики - Recall, Precision и F1-score.
# Перед этим подберем оптимальные гиперпараметры для моделей на основании метрики F1-score.

# %%
best_model = None
best_f1 = 0
for depth in range(1, 10):
    model_tree = DecisionTreeClassifier(random_state=RANDOM_STATE,
                                        max_depth=depth)
    model_tree.fit(features_train, target_train)
    predictions_valid_tree = model_tree.predict(features_valid)
    f1_tree = f1_score(target_valid, predictions_valid_tree)
    # Подберём лучшую модель среди деревьев
    if f1_tree > best_f1:
        best_model = model_tree
        best_depth = depth
        best_f1 = f1_tree
        if best_f1 > best_f1_all: # Отдельно будем сравнивать с лучшей среди всех
            best_f1_all = best_f1
            best_model_all = best_model

print('Оптимальная глубина дерева =', best_depth) 
print('Качество модели - ', f1_tree)
# Out:
# Оптимальная глубина дерева = 9
# Качество модели -  0.5261044176706827

# %%
predictions_valid_tree = best_model.predict(features_valid)

# %%
f1_tree_init = f1_score(target_valid, predictions_valid_tree)

print("Accuracy_tree:", accuracy_score(target_valid, predictions_valid_tree))
print("Recall_tree:", recall_score(target_valid, predictions_valid_tree))
print("Precision_tree:", precision_score(target_valid, predictions_valid_tree))
print("F1_tree:", f1_tree_init)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_tree_init = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_tree_init)
# Out:
# Accuracy_tree: 0.8426666666666667
# Recall_tree: 0.42810457516339867
# Precision_tree: 0.6822916666666666
# F1_tree: 0.5261044176706827
# ROC-AUC: 0.7754390142433298

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_tree, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# Матрицы ошибок наглядно демонстрируют то, что несмотря на то, что значение accuracy достаточно высокое, наблюдается остаточно сильный дисбаланс классов. Проверим и на остальных моделях.

# %% [markdown]
# ### Случайный лес

# %%
best_model = None
best_f1 = 0
for est in range(10, 101, 10):
    for depth in range(1, 10):
        model_forest = RandomForestClassifier(random_state=RANDOM_STATE,
                                              n_estimators=est, 
                                              max_depth=depth)
        model_forest.fit(features_train, target_train)
        predictions_valid_forest = model_forest.predict(features_valid)
        f1_forest = f1_score(target_valid, predictions_valid_forest)
        if f1_forest > best_f1:
            best_model = model_forest
            best_est = est
            best_depth = depth
            best_f1 = f1_forest
            if best_f1 > best_f1_all:
                best_f1_all = best_f1
                best_model_all = best_model

print('Оптимальное количество оценок =', best_est)
print('Оптимальная глубина дерева =', best_depth)
print('Качество модели - ', best_f1)
# Out:
# Оптимальное количество оценок = 10
# Оптимальная глубина дерева = 8
# Качество модели -  0.5313174946004321

# %%
predictions_valid_forest = best_model.predict(features_valid)

# %%
f1_forest_init = f1_score(target_valid, predictions_valid_forest)

print("Accuracy_forest:", accuracy_score(target_valid, predictions_valid_forest))
print("Recall_forest:", recall_score(target_valid, predictions_valid_forest))
print("Precision_forest:", precision_score(target_valid, predictions_valid_forest))
print("F1_forest:", f1_forest_init)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_forest_init = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_forest_init)
# Out:
# Accuracy_forest: 0.8553333333333333
# Recall_forest: 0.4019607843137255
# Precision_forest: 0.7834394904458599
# F1_forest: 0.5313174946004321
# ROC-AUC: 0.8589954127938166

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_forest, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# Схожая картина. Но ROC-AUC сильно выше.

# %% [markdown]
# ### Логистическая регрессия

# %%
model_log = LogisticRegression(random_state=RANDOM_STATE, solver='liblinear')
model_log.fit(features_train, target_train)
predictions_valid_log = model_log.predict(features_valid)

# %%
f1_log_init = f1_score(target_valid, predictions_valid_log)
if f1_log_init > best_f1_all:
    best_f1_all = f1_log_init
    best_model_all = model_log
    
print("Accuracy_log:", accuracy_score(target_valid, predictions_valid_log))
print("Recall_log:", recall_score(target_valid, predictions_valid_log))
print("Precision_log:", precision_score(target_valid, predictions_valid_log))
print("F1_log:", f1_log_init)

probabilities_one_valid = model_log.predict_proba(features_test)[:, 1]
roc_auc_log_init = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_log_init)
# Out:
# Accuracy_log: 0.8006666666666666
# Recall_log: 0.13398692810457516
# Precision_log: 0.5466666666666666
# F1_log: 0.2152230971128609
# ROC-AUC: 0.46728194348649565

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_log, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# Даже немного хуже

# %% [markdown]
# ### Вывод этапа

# %% [markdown]
# Без учета дисбаланса классов, модели хорошо предсказывают значение 0 (порядка 95% случаев), но плохо предсказывают 1 (около 45% для дерева и леса, 22% у логистической регрессии). Без учёта дисбаланса классов невозможно будет построить корректную модель.

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Рассмотрим 3 метода борьбы с дисбалансом классов:
#
# - Взвешивание классов
# - Увеличение выборки (upsampling)
# - Уменьшение выборки (downsampling)

# %% [markdown]
# ### Взвешивание классов

# %% [markdown]
# #### Дерево решений

# %%
best_model = None
best_f1 = 0
for depth in range(1, 10):
    model_tree = DecisionTreeClassifier(random_state=RANDOM_STATE,
                                        max_depth=depth,
                                        class_weight='balanced')
    model_tree.fit(features_train, target_train)
    predictions_valid_tree = model_tree.predict(features_valid)
    f1_tree = f1_score(target_valid, predictions_valid_tree)
    if f1_tree > best_f1:
        best_model = model_tree
        best_depth = depth
        best_f1 = f1_tree
        if best_f1 > best_f1_all:
            best_f1_all = best_f1
            best_model_all = best_model

print('Оптимальная глубина дерева =', best_depth) 
print('Качество модели - ', f1_tree)
# Out:
# Оптимальная глубина дерева = 5
# Качество модели -  0.541025641025641

# %%
predictions_valid_tree = best_model.predict(features_valid)

# %%
recall_tree_balenced = recall_score(target_valid, predictions_valid_tree)
precision_tree_balanced = precision_score(target_valid, predictions_valid_tree)
f1_tree_balanced = f1_score(target_valid, predictions_valid_tree)

print("Recall_tree:", recall_tree_balenced)
print("Precision_tree:", precision_tree_balanced)
print("F1_tree:", f1_tree_balanced)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_tree_balanced = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_tree_balanced)
# Out:
# Recall_tree: 0.7352941176470589
# Precision_tree: 0.528169014084507
# F1_tree: 0.6147540983606558
# ROC-AUC: 0.8380409673640534

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_tree, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# #### Случайный лес

# %%
best_model = None
best_f1 = 0
for est in range(10, 101, 10):
    for depth in range(1, 10):
        model_forest = RandomForestClassifier(random_state=RANDOM_STATE,
                                              n_estimators=est, 
                                              max_depth=depth,
                                              class_weight='balanced')
        model_forest.fit(features_train, target_train)
        predictions_valid_forest = model_forest.predict(features_valid)
        f1_forest = f1_score(target_valid, predictions_valid_forest)
        if f1_forest > best_f1:
            best_model = model_forest
            best_est = est
            best_depth = depth
            best_f1 = f1_forest
            if best_f1 > best_f1_all:
                best_f1_all = best_f1
                best_model_all = best_model

print('Оптимальное количество оценок =', best_est)
print('Оптимальная глубина дерева =', best_depth)
# Out:
# Оптимальное количество оценок = 80
# Оптимальная глубина дерева = 9

# %%
predictions_valid_forest = best_model.predict(features_valid)

# %%
recall_forest_balenced = recall_score(target_valid, predictions_valid_forest)
precision_forest_balanced = precision_score(target_valid, predictions_valid_forest)
f1_forest_balanced = f1_score(target_valid, predictions_valid_forest)

print("Recall_forest:", recall_forest_balenced)
print("Precision_forest:", precision_forest_balanced)
print("F1_forest:", f1_forest_balanced)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_forest_balanced = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_forest_balanced)
# Out:
# Recall_forest: 0.6895424836601307
# Precision_forest: 0.5977337110481586
# F1_forest: 0.6403641881638846
# ROC-AUC: 0.8687144874700297

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_forest, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# #### Логистическая регрессия

# %%
model_log = LogisticRegression(random_state=RANDOM_STATE,
                               solver='liblinear',
                               class_weight='balanced')

model_log.fit(features_train, target_train)
predictions_valid_log = model_log.predict(features_valid)

# %%
recall_log_balenced = recall_score(target_valid, predictions_valid_log)
precision_log_balanced = precision_score(target_valid, predictions_valid_log)
f1_log_balanced = f1_score(target_valid, predictions_valid_log)

if f1_log_balanced > best_f1_all:
    best_f1_all = f1_log_balanced
    best_model_all = model_log

print("Recall_log:", recall_log_balenced)
print("Precision_log:", precision_log_balanced)
print("F1_log:", f1_log_balanced)

probabilities_one_valid = model_log.predict_proba(features_valid)[:, 1]
roc_auc_log_balanced = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_log_balanced)
# Out:
# Recall_log: 0.7058823529411765
# Precision_log: 0.37305699481865284
# F1_log: 0.488135593220339
# ROC-AUC: 0.7701169244917399

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)
c_mat = confusion_matrix(y_pred = predictions_valid_log, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# ### Уменьшение выборки

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    # fractioning samples
    features_downsampled = pd.concat([features_zeros.sample(frac=fraction, random_state=RANDOM_STATE)] +
                                     [features_ones])
    target_downsampled = pd.concat([target_zeros.sample(frac=fraction, random_state=RANDOM_STATE)] +
                                   [target_ones])
    
    features_downsampled = shuffle(features_downsampled, random_state=RANDOM_STATE)
    target_downsampled = shuffle(target_downsampled, random_state=RANDOM_STATE)

    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)

print(features_downsampled.shape)
print(target_downsampled.shape)
# Out:
# (2820, 10)
# (2820,)

# %% [markdown]
# #### Дерево решений

# %%
best_model = None
best_f1 = 0
for depth in range(1, 10):
    model_tree = DecisionTreeClassifier(random_state=RANDOM_STATE,
                                        max_depth=depth)
    model_tree.fit(features_downsampled, target_downsampled)
    predictions_valid_tree = model_tree.predict(features_valid)
    f1_tree = f1_score(target_valid, predictions_valid_tree)
    if f1_tree > best_f1:
        best_model = model_tree
        best_depth = depth
        best_f1 = f1_tree
        if best_f1 > best_f1_all:
            best_f1_all = best_f1
            best_model_all = best_model
        
print('Оптимальная глубина дерева =', best_depth) 
print('Качество модели - ', f1_tree)
# Out:
# Оптимальная глубина дерева = 5
# Качество модели -  0.5319148936170213

# %%
predictions_valid_tree = best_model.predict(features_valid)

recall_tree_downsampled = recall_score(target_valid, predictions_valid_tree)
precision_tree_downsampled = precision_score(target_valid, predictions_valid_tree)
f1_tree_downsampled = f1_score(target_valid, predictions_valid_tree)

print("Recall_tree:", recall_tree_downsampled)
print("Precision_tree:", precision_tree_downsampled)
print("F1_tree:", f1_tree_downsampled)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_tree_downsampled = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_tree_downsampled)
# Out:
# Recall_tree: 0.7418300653594772
# Precision_tree: 0.5182648401826484
# F1_tree: 0.6102150537634409
# ROC-AUC: 0.8440746762133108

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_tree, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# #### Случайный лес

# %%
best_model = None
best_f1 = 0
for est in range(10, 101, 10):
    for depth in range(1, 10):
        model_forest = RandomForestClassifier(random_state=RANDOM_STATE,
                                              n_estimators=est, 
                                              max_depth=depth)
        model_forest.fit(features_downsampled, target_downsampled)
        predictions_valid_forest = model_forest.predict(features_valid)
        f1_forest = f1_score(target_valid, predictions_valid_forest)
        if f1_forest > best_f1:
            best_f1 = f1_forest
            best_model = model_forest
            best_est = est
            best_depth = depth
            if best_f1 > best_f1_all:
                best_f1_all = best_f1
                best_model_all = best_model

print('Оптимальное количество оценок =', best_est)
print('Оптимальная глубина дерева =', best_depth)
# Out:
# Оптимальное количество оценок = 10
# Оптимальная глубина дерева = 6

# %%
predictions_valid_forest = best_model.predict(features_valid)

recall_forest_downsampled = recall_score(target_valid, predictions_valid_forest)
precision_forest_downsampled = precision_score(target_valid, predictions_valid_forest)
f1_forest_downsampled = f1_score(target_valid, predictions_valid_forest)

print("Recall_forest:", recall_forest_downsampled)
print("Precision_forest:", precision_forest_downsampled)
print("F1_forest:", f1_forest_downsampled)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_forest_downsampled = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_forest_downsampled)
# Out:
# Recall_forest: 0.761437908496732
# Precision_forest: 0.516629711751663
# F1_forest: 0.6155878467635403
# ROC-AUC: 0.8576228090342781

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)

c_mat = confusion_matrix(y_pred = predictions_valid_forest, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# #### Логистическая регрессия

# %%
model_log = LogisticRegression(random_state=RANDOM_STATE,
                               solver='liblinear')

model_log.fit(features_downsampled, target_downsampled)
predictions_valid_log = model_log.predict(features_valid)

recall_log_downsampled = recall_score(target_valid, predictions_valid_log)
precision_log_downsampled = precision_score(target_valid, predictions_valid_log)
f1_log_downsampled = f1_score(target_valid, predictions_valid_log)

if f1_log_downsampled > best_f1_all:
    best_f1_all = f1_log_downsampled
    best_model_all = model_log

print("Recall_log:", recall_log_downsampled)
print("Precision_log:", precision_log_downsampled)
print("F1_log:", f1_log_downsampled)

probabilities_one_valid = model_log.predict_proba(features_valid)[:, 1]
roc_auc_log_downsampled = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_log_downsampled)
# Out:
# Recall_log: 0.7320261437908496
# Precision_log: 0.3739565943238731
# F1_log: 0.49502762430939223
# ROC-AUC: 0.769939019717323

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)
c_mat = confusion_matrix(y_pred = predictions_valid_log, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# ### Увеличение выборки

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    # сцепляем выборки
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    # перемешиваем значения, чтобы они не шли друг за другом 
    features_upsampled = shuffle(features_upsampled, random_state=RANDOM_STATE)
    target_upsampled = shuffle(target_upsampled, random_state=RANDOM_STATE)
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

print(features_upsampled.shape)
print(target_upsampled.shape)
# Out:
# (11278, 10)
# (11278,)

# %% [markdown]
# #### Дерево решений

# %%
best_model = None
best_f1 = 0
for depth in range(1, 10):
    model_tree = DecisionTreeClassifier(random_state=RANDOM_STATE,
                                        max_depth=depth)
    model_tree.fit(features_upsampled, target_upsampled)
    predictions_valid_tree = model_tree.predict(features_valid)
    f1_tree = f1_score(target_valid, predictions_valid_tree)
    if f1_tree > best_f1:
        best_model = model_tree
        best_depth = depth
        best_f1 = f1_tree
        if best_f1 > best_f1_all:
            best_f1_all = best_f1
            best_model_all = best_model
            
print('Оптимальная глубина дерева =', best_depth) 
print('Качество модели - ', f1_tree)
# Out:
# Оптимальная глубина дерева = 5
# Качество модели -  0.5396419437340153

# %%
predictions_valid_tree = best_model.predict(features_valid)

recall_tree_upsampled = recall_score(target_valid, predictions_valid_tree)
precision_tree_upsampled = precision_score(target_valid, predictions_valid_tree)
f1_tree_upsampled = f1_score(target_valid, predictions_valid_tree)

print("Recall_tree:", recall_tree_upsampled)
print("Precision_tree:", precision_tree_upsampled)
print("F1_tree:", f1_tree_upsampled)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_tree_upsampled = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_tree_upsampled)
# Out:
# Recall_tree: 0.7352941176470589
# Precision_tree: 0.528169014084507
# F1_tree: 0.6147540983606558
# ROC-AUC: 0.8380409673640534

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)
c_mat = confusion_matrix(y_pred = predictions_valid_tree, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# #### Случайный лес

# %%
best_model = None
best_f1 = 0
for est in range(10, 101, 10):
    for depth in range(1, 10):
        model_forest = RandomForestClassifier(random_state=RANDOM_STATE,
                                              n_estimators=est, 
                                              max_depth=depth)
        model_forest.fit(features_upsampled, target_upsampled)
        predictions_valid_forest = model_forest.predict(features_valid)
        f1_forest = f1_score(target_valid, predictions_valid_forest)
        if f1_forest > best_f1:
            best_model = model_forest
            best_est = est
            best_depth = depth
            best_f1 = f1_forest
            if best_f1 > best_f1_all:
                best_f1_all = best_f1
                best_model_all = best_model

print('Оптимальное количество оценок =', best_est)
print('Оптимальная глубина дерева =', best_depth)
# Out:
# Оптимальное количество оценок = 100
# Оптимальная глубина дерева = 9

# %%
predictions_valid_forest = best_model.predict(features_valid)

recall_forest_upsampled = recall_score(target_valid, predictions_valid_forest)
precision_forest_upsampled = precision_score(target_valid, predictions_valid_forest)
f1_forest_upsampled = f1_score(target_valid, predictions_valid_forest)

print("Recall_forest:", recall_forest_upsampled)
print("Precision_forest:", precision_forest_upsampled)
print("F1_forest:", f1_forest_upsampled)

probabilities_one_valid = best_model.predict_proba(features_valid)[:, 1]
roc_auc_forest_upsampled = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_forest_upsampled)
# Out:
# Recall_forest: 0.7189542483660131
# Precision_forest: 0.5555555555555556
# F1_forest: 0.6267806267806268
# ROC-AUC: 0.8679015995007718

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)
c_mat = confusion_matrix(y_pred = predictions_valid_forest, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# #### Логистическая регрессия

# %%
model_log = LogisticRegression(random_state=RANDOM_STATE,
                               solver='liblinear')
model_log.fit(features_upsampled, target_upsampled)
predictions_valid_log = model_log.predict(features_valid)

recall_log_upsampled = recall_score(target_valid, predictions_valid_log)
precision_log_upsampled = precision_score(target_valid, predictions_valid_log)
f1_log_upsampled = f1_score(target_valid, predictions_valid_log)

if f1_log_upsampled > best_f1_all:
    best_f1_all = f1_log_up
    best_model_all = model_log

print("Recall_log:", recall_log_upsampled)
print("Precision_log:", precision_log_upsampled)
print("F1_log:", f1_log_upsampled)

probabilities_one_valid = model_log.predict_proba(features_valid)[:, 1]
roc_auc_log_upsampled = roc_auc_score(target_valid, probabilities_one_valid)
print("ROC-AUC:", roc_auc_log_upsampled)
# Out:
# Recall_log: 0.7091503267973857
# Precision_log: 0.36717428087986465
# F1_log: 0.483835005574136
# ROC-AUC: 0.770185349404977

# %%
plt.figure(figsize=figsize(2))
ax1 = plt.subplot(1,2,1)
c_mat = confusion_matrix(y_pred = predictions_valid_log, y_true=target_valid,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(ax=ax1,cmap=cm)
ax2 = plt.subplot(1,2,2)
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
None

# %% [markdown]
# ### Вывод этапа

# %%
model_name = ['Tree', 'Forest', 'Log']
initial_values = [f1_tree_init, f1_forest_init, f1_log_init]
weighting_values = [f1_tree_balanced, f1_forest_balanced, f1_log_balanced]
down_values = [f1_tree_downsampled, f1_forest_downsampled, f1_log_downsampled]
up_values = [f1_tree_upsampled, f1_forest_upsampled, f1_log_upsampled]

data_metrics = pd.DataFrame({'Initial': initial_values,
                           'Weighing': weighting_values,
                           'Downsampling': down_values,
                           'Upsampling': up_values })
data_metrics.index=model_name
data_metrics.style.background_gradient(cmap=cm,axis=None)
# Out:
# <style type="text/css">
# #T_90d38_row0_col0 {
#   background-color: #1d6187;
#   color: #f1f1f1;
# }
# #T_90d38_row0_col1, #T_90d38_row0_col3 {
#   background-color: #2a3c77;
#   color: #f1f1f1;
# }
# #T_90d38_row0_col2 {
#   background-color: #2a3e78;
#   color: #f1f1f1;
# }
# #T_90d38_row1_col0 {
#   background-color: #1d5f87;
#   color: #f1f1f1;
# }
# #T_90d38_row1_col1 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_90d38_row1_col2 {
#   background-color: #2a3b76;
#   color: #f1f1f1;
# }
# #T_90d38_row1_col3 {
#   background-color: #2b3774;
#   color: #f1f1f1;
# }
# #T_90d38_row2_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_90d38_row2_col1 {
#   background-color: #1f6f8a;
#   color: #f1f1f1;
# }
# #T_90d38_row2_col2 {
#   background-color: #1e6d8a;
#   color: #f1f1f1;
# }
# #T_90d38_row2_col3 {
#   background-color: #20718b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90d38">
#   <thead>
#     <tr>
# ...

# %%
model_name = ['Tree', 'Forest', 'Log']
initial_values = [roc_auc_tree_init, roc_auc_forest_init, roc_auc_log_init]
weighting_values = [roc_auc_tree_balanced, roc_auc_forest_balanced, roc_auc_log_balanced]
down_values = [roc_auc_tree_downsampled, roc_auc_forest_downsampled, roc_auc_log_downsampled]
up_values = [roc_auc_tree_upsampled, roc_auc_forest_upsampled, roc_auc_log_upsampled]

data_metrics = pd.DataFrame({'Initial': initial_values,
                           'Weighing': weighting_values,
                           'Downsampling': down_values,
                           'Upsampling': up_values })
data_metrics.index=model_name
data_metrics.style.background_gradient(cmap=cm,axis=None)
# Out:
# <style type="text/css">
# #T_ab81d_row0_col0 {
#   background-color: #1f5b86;
#   color: #f1f1f1;
# }
# #T_ab81d_row0_col1, #T_ab81d_row0_col3 {
#   background-color: #2a3f78;
#   color: #f1f1f1;
# }
# #T_ab81d_row0_col2 {
#   background-color: #2a3c77;
#   color: #f1f1f1;
# }
# #T_ab81d_row1_col0 {
#   background-color: #2c3574;
#   color: #f1f1f1;
# }
# #T_ab81d_row1_col1, #T_ab81d_row1_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_ab81d_row1_col2 {
#   background-color: #2b3674;
#   color: #f1f1f1;
# }
# #T_ab81d_row2_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_ab81d_row2_col1, #T_ab81d_row2_col2, #T_ab81d_row2_col3 {
#   background-color: #1e5d86;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab81d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab81d_level0_col0" class="col_heading level0 col0" >Initial</th>
#       <th id="T_ab81d_level0_col1" class="col_heading level0 col1" >Weighing</th>
# ...

# %%
print('best f1:',best_f1_all)
# Out:
# best f1: 0.6403641881638846

# %% [markdown]
# Учёт дисбаланса классов повышает качество модели. Наилучший результат показывает модель случайного леса с взвешиванием классов - F1 = 0.64. Наибольший ROC-AUC достигается у той же модели, но все модели случайного леса обладают очень высоким ROC-AUC.

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Сейчас, когда гиперпараметры подобраны и валидационная выборка не нужна, можно обучить модель на большой выборке (обучающая + валидационная)

# %%
features_train_new = pd.concat([features_train, features_valid])
target_train_new = pd.concat([target_train, target_valid])
best_model_all.fit(features_train_new, target_train_new)
None

# %%
predictions_test = best_model_all.predict(features_test)

print("Recall:", recall_score(target_test, predictions_test))
print("Precision:", precision_score(target_test, predictions_test))
print("F1:", f1_score(target_test, predictions_test))

probabilities_test = best_model_all.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]
print("ROC-AUC_forest:", roc_auc_score(target_test, probabilities_one_test))
# Out:
# Recall: 0.7344262295081967
# Precision: 0.5503685503685504
# F1: 0.6292134831460675
# ROC-AUC_forest: 0.8710172165443447

# %%
plt.figure(figsize=figsize())
c_mat = confusion_matrix(y_pred = predictions_test, y_true=target_test,
                      normalize='true')

ConfusionMatrixDisplay(confusion_matrix=c_mat).plot(cmap=cm)
None

# %%
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test) 

plt.figure(figsize=figsize())
plt.plot(fpr, tpr, linestyle='solid', color=new_color(3))
plt.plot([0, 1], [0, 1], linestyle='--',color=new_color(14))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel('False Positive Rate',fontsize=20)
plt.ylabel('True Positive Rate',fontsize=20)
plt.title('ROC-кривая',fontsize=20)
plt.show()

# %% [markdown]
# Показатели тестовой выборки F1 - 0.62, граничная F1-score = 0.59 преодолена. Значение ROC-AUC - 0.86

# %% [markdown]
# ## Вывод

# %% [markdown]
# Изучен датафрейм `Churn.csv`:
# - 14 столбцов:
#     - `RowNumber` — индекс строки в данных
#     - `CustomerId` — уникальный идентификатор клиента
#     - `Surname` — фамилия
#     - `CreditScore` — кредитный рейтинг
#     - `Geography` — страна проживания
#     - `Gender` — пол
#     - `Age` — возраст
#     - `Tenure` — сколько лет человек является клиентом банка
#     - `Balance` — баланс на счёте
#     - `NumOfProducts` — количество продуктов банка, используемых клиентом
#     - `HasCrCard` — наличие кредитной карты
#     - `IsActiveMember` — активность клиента
#     - `EstimatedSalary` — предполагаемая зарплата
# - 10000 строк
# - Пропуски в строкe `Tenure` - 9.09% данных пропущено. Заменены на основе 5 ближайших соседей.
# - Дубликатов не наблюдается
#
# - Из рассмотрения убраны столбцы `RowNumber`,`CustomerId`, `Surname` как не несущие обучающей нагрузки
# - Категориальные данные из столбцов `Geography` и `Gender` подготовлены методом `OHE`
# - Проведено разбиение на обучающую, валидационную и тестовую выборки в соотношении 70%, 15% и 15% соответственно
# - Проведено маштабирование количественных данных
# - Установлено, что есть дисбаланс в целевом столбце. Значений 0 в 4 раза больше чем значений 1
#
# - В рамках борьбы с дисбалансом классов было рассмотрено 3 метода:
#     - Взвешивание классов
#     - Увеличение выборки
#     - Уменьшение выборки
#
# - В результате борьбы с дисбанансом классов были получены следующие выводы:
#     - Наибольшее значение метрики F1-score получено на модели Случайный лес при помощи взвешивания классов. Результаты тестирования:
#         - F1-score = 0.63 (выше необходимого значения)
#         - AUC-ROC = 0.87 (достаточно близко к единице)
